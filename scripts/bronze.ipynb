# %% [markdown]
# # Script bronze

# %% [markdown]
# Primeiramente vamos fazer a validação de que os arquivos foram criados, a quantidade de partições está correta e que cada partição pode ser lida.

# %%
from pathlib import Path

files = list(OUTPUT_DIR.glob("*.parquet"))

print(f"Arquivos gerados: {len(files)}")

test = pl.read_parquet(files[0])

print(test.head())
print(test.schema)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
#       2
# ----> 3 files = list(OUTPUT_DIR.glob("*.parquet"))
#       4
#       5 print(f"Arquivos gerados: {len(files)}")
#       6
#
# NameError: name 'OUTPUT_DIR' is not defined
